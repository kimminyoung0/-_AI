# %%
import pandas as pd
import numpy as np
import pprint
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
sub = pd.read_csv('./data/sample_submission.csv')
sec = pd.read_csv('./data/external_open/대구 보안등 정보_re.csv')
child = pd.read_csv('./data/external_open/대구 어린이 보호 구역 정보_re.csv')
park = pd.read_csv('./data/external_open/대구 주차장 정보_re.csv')
cctv = pd.read_csv('./data/external_open/대구 CCTV 정보_re.csv')
# Out:
# /var/folders/rc/3jzqjhp56_v2qxb49fkb1x880000gn/T/ipykernel_1573/4116356519.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   sec = pd.read_csv('./data/external_open/대구 보안등 정보_re.csv')

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
train #(39609, 23)
# Out:
#                    ID           사고일시   요일 기상상태              시군구  \
# 0      ACCIDENT_00000  2019-01-01 00  화요일   맑음     대구광역시 중구 대신동
# 1      ACCIDENT_00001  2019-01-01 00  화요일   흐림    대구광역시 달서구 감삼동
# 2      ACCIDENT_00002  2019-01-01 01  화요일   맑음    대구광역시 수성구 두산동
# 3      ACCIDENT_00003  2019-01-01 02  화요일   맑음     대구광역시 북구 복현동
# 4      ACCIDENT_00004  2019-01-01 04  화요일   맑음     대구광역시 동구 신암동
# ...               ...            ...  ...  ...              ...
# 39604  ACCIDENT_39604  2021-12-31 19  금요일   맑음  대구광역시 수성구 수성동3가
# 39605  ACCIDENT_39605  2021-12-31 19  금요일   맑음    대구광역시 달서구 상인동
# 39606  ACCIDENT_39606  2021-12-31 21  금요일   맑음    대구광역시 달서구 월성동
# 39607  ACCIDENT_39607  2021-12-31 22  금요일   맑음     대구광역시 달서구 장동
# 39608  ACCIDENT_39608  2021-12-31 23  금요일   맑음     대구광역시 서구 비산동
#
#                   도로형태 노면상태  사고유형 사고유형 - 세부분류       법규위반 가해운전자 차종 가해운전자 성별  \
# 0             단일로 - 기타   건조  차대사람  길가장자리구역통행중    안전운전불이행       승용        여
# 1             단일로 - 기타   건조  차대사람       보도통행중         기타       승용        남
# 2             단일로 - 기타   건조  차대사람       차도통행중    안전운전불이행       승용        남
# 3             단일로 - 기타   건조   차대차          추돌    안전운전불이행       승용        남
# 4             단일로 - 기타   건조   차대차          추돌    안전운전불이행       승용        남
# ...                ...  ...   ...         ...        ...      ...      ...
# 39604       교차로 - 교차로안   건조   차대차        측면충돌       신호위반       승용        여
# 39605         단일로 - 기타   건조   차대차        측면충돌    안전거리미확보       승용        여
# 39606       교차로 - 교차로안   건조   차대차        측면충돌  교차로운행방법위반       승용        남
# 39607          기타 - 기타   건조   차대차          추돌    안전운전불이행       승용        남
# 39608  단일로 - 지하차도(도로)내   건조   차대차        측면충돌    안전운전불이행       승용        남
#
#       가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도  사망자수  중상자수  \
# 0          51세       상해없음      보행자        여      70세         중상     0     1
# 1          39세       상해없음      보행자        남      61세         경상     0     0
# 2          70세       상해없음      보행자        남      38세         경상     0     0
# 3          49세       상해없음       승용        남      36세         중상     0     1
# 4          30세       상해없음       승용        남      52세         경상     0     0
# ...        ...        ...      ...      ...      ...        ...   ...   ...
# 39604      52세       상해없음       이륜        남      28세         경상     0     0
# 39605      60세       상해없음       승용        남      52세         경상     0     0
# 39606      60세         중상       승용        남      73세         중상     0     2
# 39607      40세       상해없음       승용        여      57세         경상     0     0
# 39608      27세       상해없음       승용        남      33세         경상     0     0
#
#        경상자수  부상자수  ECLO
# 0         0     0     5
# 1         1     0     3
# 2         1     0     3
# 3         0     0     5
# 4         1     0     3
# ...     ...   ...   ...
# 39604     1     0     3
# 39605     1     0     3
# 39606     0     0    10
# 39607     1     0     3
# 39608     2     0     6
#
# [39609 rows x 23 columns]

# %% [markdown]
# #### test의 column들만 사용하여 train 데이터 구성

# %%
train = train[test.columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39609 entries, 0 to 39608
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      39609 non-null  object
#  1   사고일시    39609 non-null  object
#  2   요일      39609 non-null  object
#  3   기상상태    39609 non-null  object
#  4   시군구     39609 non-null  object
#  5   도로형태    39609 non-null  object
#  6   노면상태    39609 non-null  object
#  7   사고유형    39609 non-null  object
# dtypes: object(8)
# memory usage: 2.4+ MB

# %% [markdown]
# ### 도로명 주소를 지번 주소로 바꾼 후, 시군구 나눌 예정

# %% [markdown]
# '로'는 포함, '동'은 미포함

# %%
train[(train['시군구'].str.contains('로'))&(~train['시군구'].str.contains('동'))]
# Out:
#                    ID           사고일시   요일 기상상태             시군구  \
# 56     ACCIDENT_00056  2019-01-03 03  목요일   맑음    대구광역시 중구 남성로
# 92     ACCIDENT_00092  2019-01-04 05  금요일   맑음  대구광역시 중구 태평로3가
# 746    ACCIDENT_00746  2019-01-24 15  목요일   맑음  대구광역시 중구 태평로3가
# 870    ACCIDENT_00870  2019-01-27 22  일요일   맑음  대구광역시 중구 서문로2가
# 1186   ACCIDENT_01186  2019-02-04 06  월요일   맑음  대구광역시 중구 태평로3가
# ...               ...            ...  ...  ...             ...
# 38251  ACCIDENT_38251  2021-11-20 20  토요일   맑음  대구광역시 중구 북성로2가
# 38473  ACCIDENT_38473  2021-11-26 18  금요일   맑음  대구광역시 중구 태평로3가
# 38663  ACCIDENT_38663  2021-12-02 12  목요일   맑음   대구광역시 중구 시장북로
# 38703  ACCIDENT_38703  2021-12-03 15  금요일   맑음  대구광역시 중구 태평로3가
# 38742  ACCIDENT_38742  2021-12-04 14  토요일   맑음  대구광역시 중구 태평로2가
#
#                  도로형태 노면상태  사고유형
# 56         교차로 - 교차로안   건조   차대차
# 92     교차로 - 교차로횡단보도내   건조  차대사람
# 746          단일로 - 기타   건조   차대차
# 870       교차로 - 교차로부근   건조   차대차
# 1186      교차로 - 교차로부근   건조   차대차
# ...               ...  ...   ...
# 38251      교차로 - 교차로안   건조   차대차
# 38473      교차로 - 교차로안   건조   차대차
# 38663      교차로 - 교차로안   건조   차대차
# 38703        단일로 - 기타   건조   차대차
# 38742     교차로 - 교차로부근   건조   차대차
#
# [206 rows x 8 columns]

# %%
sec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71913 entries, 0 to 71912
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   보안등위치명    71913 non-null  object
#  1   설치개수      71913 non-null  int64
#  2   소재지도로명주소  34646 non-null  object
#  3   소재지지번주소   71913 non-null  object
#  4   위도        43602 non-null  float64
#  5   경도        43602 non-null  float64
#  6   설치연도      29397 non-null  float64
#  7   설치형태      35373 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 4.4+ MB
